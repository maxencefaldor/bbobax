# %% [markdown]
# # Black-Box Optimization [![Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/maxencefaldor/bbobax/blob/main/notebooks/bbo.ipynb)

# %% [markdown]
# ## Install

# %% [markdown]
# You will need Python 3.11 or later, and a working JAX installation. For example, you can install JAX with:

# %%
# %pip install -U "jax[cuda]"

# %% [markdown]
# Then, install CAX from PyPi:

# %%
# %pip install -U "bbobax[notebooks]"

# %% [markdown]
# # Import

# %%
import jax
import jax.numpy as jnp
